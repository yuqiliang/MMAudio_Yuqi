# %%
import torch
print(torch.backends.mps.is_available())  # 如果是 True，说明 MPS 可用
# Out:
# True

# %% [markdown]
# 确保环境正确激活：
# 手动激活
# source mmaudio/bin/activate
# 然后运行：
# python train.py --model_path ./checkpoint --data_path ./data
