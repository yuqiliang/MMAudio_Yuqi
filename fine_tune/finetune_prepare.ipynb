# %% [markdown]
# ## tsv genertor

# %%
import pandas as pd
import os
from pathlib import Path

def create_video_tsv_from_local():

    video_dir = Path('/Users/yuqiliang/Documents/UCLPhD/pilot_study/output_split_stride10')
    output_file = './training/video_train_stride_10.tsv'

    # make sure the output directory exists
    os.makedirs(os.path.dirname(output_file), exist_ok=True)

    video_files = []
    labels = []

   # search for video files with common extensions
    video_extensions = ['.mp4', '.avi', '.mov', '.mkv']
    all_videos = []

    for ext in video_extensions:
        all_videos.extend(video_dir.glob(f'*{ext}'))
        all_videos.extend(video_dir.glob(f'*{ext.upper()}'))

    print(f"processed {len(all_videos)} videos...")

    for video_path in sorted(all_videos):
        try:
            # filter out non-video files
            video_id = video_path.stem
            video_files.append(video_id)

            # assign a label for the video
            label = "audio from video"  
            labels.append(label)

            print(f"  ✓ {video_path.name} -> {video_id}")

        except Exception as e:
            print(f"  ❌ processed {video_path.name} error : {e}")
            continue

    if not video_files:
        print("❌ no video files found in the directory.")
        return None

    # 构建 DataFrame
    df = pd.DataFrame({'id': video_files, 'label': labels})

    # 保存到本地
    df.to_csv(output_file, sep='\t', index=False)


    print(f"✅ TSV file created at {output_file}")
    print(f"Total videos processed: {len(video_files)}")
    print(f"Total labels assigned: {len(labels)}")


    return df


# check if the TSV file already exists
local_tsv = Path('./training/my_video_train.tsv')

if not local_tsv.exists():
    print("📋 create new...")
    train_df = create_video_tsv_from_local()
else:
    print("📋 using tsv...")
    train_df = pd.read_csv(local_tsv, sep='\t')

if train_df is not None:
    print("\n📄 TSV:")
    print(train_df.head())
else:
    print("❌ tsv file creation failed or no videos found.")
# Out:
# 📋 create new...
# processed 2692 videos...
#   ✓ CamdenMarket1_EQR_720p_0000.mp4 -> CamdenMarket1_EQR_720p_0000
#   ✓ CamdenMarket1_EQR_720p_0001.mp4 -> CamdenMarket1_EQR_720p_0001
#   ✓ CamdenMarket1_EQR_720p_0002.mp4 -> CamdenMarket1_EQR_720p_0002
#   ✓ CamdenMarket1_EQR_720p_0003.mp4 -> CamdenMarket1_EQR_720p_0003
#   ✓ CamdenMarket1_EQR_720p_0004.mp4 -> CamdenMarket1_EQR_720p_0004
#   ✓ CamdenMarket1_EQR_720p_0005.mp4 -> CamdenMarket1_EQR_720p_0005
#   ✓ CamdenMarket1_EQR_720p_0006.mp4 -> CamdenMarket1_EQR_720p_0006
#   ✓ CamdenMarket1_EQR_720p_0007.mp4 -> CamdenMarket1_EQR_720p_0007
#   ✓ CamdenMarket1_EQR_720p_0008.mp4 -> CamdenMarket1_EQR_720p_0008
#   ✓ CamdenMarket1_EQR_720p_0009.mp4 -> CamdenMarket1_EQR_720p_0009
#   ✓ CamdenMarket1_EQR_720p_0010.mp4 -> CamdenMarket1_EQR_720p_0010
#   ✓ CamdenMarket1_EQR_720p_0011.mp4 -> CamdenMarket1_EQR_720p_0011
#   ✓ CamdenMarket1_EQR_720p_0012.mp4 -> CamdenMarket1_EQR_720p_0012
#   ✓ CamdenMarket1_EQR_720p_0013.mp4 -> CamdenMarket1_EQR_720p_0013
#   ✓ CamdenMarket1_EQR_720p_0014.mp4 -> CamdenMarket1_EQR_720p_0014
#   ✓ CamdenMarket1_EQR_720p_0015.mp4 -> CamdenMarket1_EQR_720p_0015
#   ✓ CamdenMarket1_EQR_720p_0016.mp4 -> CamdenMarket1_EQR_720p_0016
#   ✓ CamdenMarket1_EQR_720p_0017.mp4 -> CamdenMarket1_EQR_720p_0017
#   ✓ CamdenMarket1_EQR_720p_0018.mp4 -> CamdenMarket1_EQR_720p_0018
#   ✓ CamdenMarket1_EQR_720p_0019.mp4 -> CamdenMarket1_EQR_720p_0019
#   ✓ CamdenMarket1_EQR_720p_0020.mp4 -> CamdenMarket1_EQR_720p_0020
#   ✓ CamdenMarket1_EQR_720p_0021.mp4 -> CamdenMarket1_EQR_720p_0021
#   ✓ CamdenMarket1_EQR_720p_0022.mp4 -> CamdenMarket1_EQR_720p_0022
#   ✓ CamdenMarket1_EQR_720p_0023.mp4 -> CamdenMarket1_EQR_720p_0023
#   ✓ CamdenMarket1_EQR_720p_0024.mp4 -> CamdenMarket1_EQR_720p_0024
#   ✓ CamdenMarket1_EQR_720p_0025.mp4 -> CamdenMarket1_EQR_720p_0025
#   ✓ CamdenMarket1_EQR_720p_0026.mp4 -> CamdenMarket1_EQR_720p_0026
#   ✓ CamdenMarket1_EQR_720p_0027.mp4 -> CamdenMarket1_EQR_720p_0027
#   ✓ CamdenMarket1_EQR_720p_0028.mp4 -> CamdenMarket1_EQR_720p_0028
#   ✓ CamdenMarket1_EQR_720p_0029.mp4 -> CamdenMarket1_EQR_720p_0029
#   ✓ CamdenMarket1_EQR_720p_0030.mp4 -> CamdenMarket1_EQR_720p_0030
#   ✓ CamdenMarket1_EQR_720p_0031.mp4 -> CamdenMarket1_EQR_720p_0031
#   ✓ CamdenMarket1_EQR_720p_0032.mp4 -> CamdenMarket1_EQR_720p_0032
#   ✓ CamdenMarket1_EQR_720p_0033.mp4 -> CamdenMarket1_EQR_720p_0033
#   ✓ CamdenMarket1_EQR_720p_0034.mp4 -> CamdenMarket1_EQR_720p_0034
#   ✓ CamdenMarket1_EQR_720p_0035.mp4 -> CamdenMarket1_EQR_720p_0035
#   ✓ CamdenMarket1_EQR_720p_0036.mp4 -> CamdenMarket1_EQR_720p_0036
#   ✓ CamdenMarket1_EQR_720p_0037.mp4 -> CamdenMarket1_EQR_720p_0037
#   ✓ CamdenMarket1_EQR_720p_0038.mp4 -> CamdenMarket1_EQR_720p_0038
#   ✓ CamdenMarket1_EQR_720p_0039.mp4 -> CamdenMarket1_EQR_720p_0039
#   ✓ CamdenMarket1_EQR_720p_0040.mp4 -> CamdenMarket1_EQR_720p_0040
#   ✓ CamdenMarket1_EQR_720p_0041.mp4 -> CamdenMarket1_EQR_720p_0041
#   ✓ CamdenMarket1_EQR_720p_0042.mp4 -> CamdenMarket1_EQR_720p_0042
#   ✓ CamdenMarket1_EQR_720p_0043.mp4 -> CamdenMarket1_EQR_720p_0043
#   ✓ CamdenMarket1_EQR_720p_0044.mp4 -> CamdenMarket1_EQR_720p_0044
#   ✓ CamdenMarket1_EQR_720p_0045.mp4 -> CamdenMarket1_EQR_720p_0045
#   ✓ CamdenMarket1_EQR_720p_0046.mp4 -> CamdenMarket1_EQR_720p_0046
#   ✓ CamdenMarket1_EQR_720p_0047.mp4 -> CamdenMarket1_EQR_720p_0047
#   ✓ CamdenMarket1_EQR_720p_0048.mp4 -> CamdenMarket1_EQR_720p_0048
#   ✓ CamdenMarket1_EQR_720p_0049.mp4 -> CamdenMarket1_EQR_720p_0049
#   ✓ CamdenMarket1_EQR_720p_0050.mp4 -> CamdenMarket1_EQR_720p_0050
#   ✓ CamdenMarket1_EQR_720p_0051.mp4 -> CamdenMarket1_EQR_720p_0051
#   ✓ CamdenMarket1_EQR_720p_0052.mp4 -> CamdenMarket1_EQR_720p_0052
#   ✓ CamdenMarket1_EQR_720p_0053.mp4 -> CamdenMarket1_EQR_720p_0053
#   ✓ CamdenMarket1_EQR_720p_0054.mp4 -> CamdenMarket1_EQR_720p_0054
#   ✓ CamdenMarket1_EQR_720p_0055.mp4 -> CamdenMarket1_EQR_720p_0055
#   ✓ CamdenMarket1_EQR_720p_0056.mp4 -> CamdenMarket1_EQR_720p_0056
#   ✓ CamdenMarket1_EQR_720p_0057.mp4 -> CamdenMarket1_EQR_720p_0057
#   ✓ CamdenMarket1_EQR_720p_0058.mp4 -> CamdenMarket1_EQR_720p_0058
#   ✓ CamdenMarket1_EQR_720p_0059.mp4 -> CamdenMarket1_EQR_720p_0059
#   ✓ CamdenMarket1_EQR_720p_0060.mp4 -> CamdenMarket1_EQR_720p_0060
#   ✓ CamdenMarket1_EQR_720p_0061.mp4 -> CamdenMarket1_EQR_720p_0061
#   ✓ CamdenMarket1_EQR_720p_0062.mp4 -> CamdenMarket1_EQR_720p_0062
#   ✓ CamdenMarket1_EQR_720p_0063.mp4 -> CamdenMarket1_EQR_720p_0063
#   ✓ CamdenMarket1_EQR_720p_0064.mp4 -> CamdenMarket1_EQR_720p_0064
#   ✓ CamdenMarket1_EQR_720p_0065.mp4 -> CamdenMarket1_EQR_720p_0065
#   ✓ CamdenMarket1_EQR_720p_0066.mp4 -> CamdenMarket1_EQR_720p_0066
#   ✓ CamdenMarket1_EQR_720p_0067.mp4 -> CamdenMarket1_EQR_720p_0067
#   ✓ CamdenMarket1_EQR_720p_0068.mp4 -> CamdenMarket1_EQR_720p_0068
#   ✓ CamdenMarket1_EQR_720p_0069.mp4 -> CamdenMarket1_EQR_720p_0069
#   ✓ CamdenMarket1_EQR_720p_0070.mp4 -> CamdenMarket1_EQR_720p_0070
#   ✓ CamdenMarket1_EQR_720p_0071.mp4 -> CamdenMarket1_EQR_720p_0071
#   ✓ CamdenMarket1_EQR_720p_0072.mp4 -> CamdenMarket1_EQR_720p_0072
#   ✓ CamdenMarket1_EQR_720p_0073.mp4 -> CamdenMarket1_EQR_720p_0073
#   ✓ CamdenMarket1_EQR_720p_0074.mp4 -> CamdenMarket1_EQR_720p_0074
#   ✓ CamdenTown3_EQR_720p_0046.mp4 -> CamdenTown3_EQR_720p_0046
#   ✓ CamdenTown3_EQR_720p_0047.mp4 -> CamdenTown3_EQR_720p_0047
#   ✓ CamdenTown3_EQR_720p_0048.mp4 -> CamdenTown3_EQR_720p_0048
#   ✓ CamdenTown3_EQR_720p_0049.mp4 -> CamdenTown3_EQR_720p_0049
#   ✓ CamdenTown3_EQR_720p_0050.mp4 -> CamdenTown3_EQR_720p_0050
#   ✓ CamdenTown3_EQR_720p_0051.mp4 -> CamdenTown3_EQR_720p_0051
#   ✓ CamdenTown3_EQR_720p_0052.mp4 -> CamdenTown3_EQR_720p_0052
#   ✓ CamdenTown3_EQR_720p_0053.mp4 -> CamdenTown3_EQR_720p_0053
#   ✓ CamdenTown3_EQR_720p_0054.mp4 -> CamdenTown3_EQR_720p_0054
#   ✓ CamdenTown3_EQR_720p_0055.mp4 -> CamdenTown3_EQR_720p_0055
#   ✓ CamdenTown3_EQR_720p_0056.mp4 -> CamdenTown3_EQR_720p_0056
#   ✓ CamdenTown3_EQR_720p_0057.mp4 -> CamdenTown3_EQR_720p_0057
#   ✓ CamdenTown3_EQR_720p_0058.mp4 -> CamdenTown3_EQR_720p_0058
#   ✓ CamdenTown3_EQR_720p_0059.mp4 -> CamdenTown3_EQR_720p_0059
#   ✓ CamdenTown3_EQR_720p_0060.mp4 -> CamdenTown3_EQR_720p_0060
#   ✓ CamdenTown3_EQR_720p_0061.mp4 -> CamdenTown3_EQR_720p_0061
#   ✓ CamdenTown3_EQR_720p_0062.mp4 -> CamdenTown3_EQR_720p_0062
#   ✓ CamdenTown3_EQR_720p_0063.mp4 -> CamdenTown3_EQR_720p_0063
#   ✓ CamdenTown3_EQR_720p_0064.mp4 -> CamdenTown3_EQR_720p_0064
#   ✓ CamdenTown3_EQR_720p_0065.mp4 -> CamdenTown3_EQR_720p_0065
#   ✓ CamdenTown3_EQR_720p_0066.mp4 -> CamdenTown3_EQR_720p_0066
#   ✓ CamdenTown3_EQR_720p_0067.mp4 -> CamdenTown3_EQR_720p_0067
#   ✓ CamdenTown3_EQR_720p_0068.mp4 -> CamdenTown3_EQR_720p_0068
#   ✓ CamdenTown3_EQR_720p_0069.mp4 -> CamdenTown3_EQR_720p_0069
#   ✓ CamdenTown3_EQR_720p_0070.mp4 -> CamdenTown3_EQR_720p_0070
#   ✓ CamdenTown3_EQR_720p_0071.mp4 -> CamdenTown3_EQR_720p_0071
#   ✓ CamdenTown3_EQR_720p_0072.mp4 -> CamdenTown3_EQR_720p_0072
#   ✓ CamdenTown3_EQR_720p_0073.mp4 -> CamdenTown3_EQR_720p_0073
#   ✓ CamdenTown3_EQR_720p_0074.mp4 -> CamdenTown3_EQR_720p_0074
#   ✓ CamdenTown3_EQR_720p_0075.mp4 -> CamdenTown3_EQR_720p_0075
#   ✓ CamdenTown3_EQR_720p_0076.mp4 -> CamdenTown3_EQR_720p_0076
#   ✓ CamdenTown3_EQR_720p_0077.mp4 -> CamdenTown3_EQR_720p_0077
#   ✓ CamdenTown3_EQR_720p_0078.mp4 -> CamdenTown3_EQR_720p_0078
#   ✓ CamdenTown3_EQR_720p_0079.mp4 -> CamdenTown3_EQR_720p_0079
#   ✓ CamdenTown3_EQR_720p_0080.mp4 -> CamdenTown3_EQR_720p_0080
#   ✓ CamdenTown3_EQR_720p_0081.mp4 -> CamdenTown3_EQR_720p_0081
#   ✓ CamdenTown3_EQR_720p_0082.mp4 -> CamdenTown3_EQR_720p_0082
#   ✓ CamdenTown3_EQR_720p_0083.mp4 -> CamdenTown3_EQR_720p_0083
#   ✓ CamdenTown3_EQR_720p_0084.mp4 -> CamdenTown3_EQR_720p_0084
#   ✓ CamdenTown3_EQR_720p_0085.mp4 -> CamdenTown3_EQR_720p_0085
#   ✓ CamdenTown3_EQR_720p_0086.mp4 -> CamdenTown3_EQR_720p_0086
#   ✓ CamdenTown3_EQR_720p_0087.mp4 -> CamdenTown3_EQR_720p_0087
#   ✓ CamdenTown3_EQR_720p_0088.mp4 -> CamdenTown3_EQR_720p_0088
#   ✓ CamdenTown3_EQR_720p_0089.mp4 -> CamdenTown3_EQR_720p_0089
#   ✓ CamdenTown3_EQR_720p_0090.mp4 -> CamdenTown3_EQR_720p_0090
#   ✓ CamdenTown3_EQR_720p_0091.mp4 -> CamdenTown3_EQR_720p_0091
#   ✓ CamdenTown3_EQR_720p_0092.mp4 -> CamdenTown3_EQR_720p_0092
#   ✓ CamdenTown4_EQR_720p_0001.mp4 -> CamdenTown4_EQR_720p_0001
#   ✓ CamdenTown4_EQR_720p_0002.mp4 -> CamdenTown4_EQR_720p_0002
#   ✓ CamdenTown4_EQR_720p_0003.mp4 -> CamdenTown4_EQR_720p_0003
#   ✓ CamdenTown4_EQR_720p_0004.mp4 -> CamdenTown4_EQR_720p_0004
#   ✓ CamdenTown4_EQR_720p_0005.mp4 -> CamdenTown4_EQR_720p_0005
#   ✓ CamdenTown4_EQR_720p_0006.mp4 -> CamdenTown4_EQR_720p_0006
#   ✓ CamdenTown4_EQR_720p_0007.mp4 -> CamdenTown4_EQR_720p_0007
#   ✓ CamdenTown4_EQR_720p_0008.mp4 -> CamdenTown4_EQR_720p_0008
#   ✓ CamdenTown4_EQR_720p_0009.mp4 -> CamdenTown4_EQR_720p_0009
#   ✓ CamdenTown4_EQR_720p_0010.mp4 -> CamdenTown4_EQR_720p_0010
#   ✓ CamdenTown4_EQR_720p_0011.mp4 -> CamdenTown4_EQR_720p_0011
#   ✓ CamdenTown4_EQR_720p_0012.mp4 -> CamdenTown4_EQR_720p_0012
#   ✓ CamdenTown4_EQR_720p_0013.mp4 -> CamdenTown4_EQR_720p_0013
#   ✓ CamdenTown4_EQR_720p_0014.mp4 -> CamdenTown4_EQR_720p_0014
#   ✓ CamdenTown4_EQR_720p_0015.mp4 -> CamdenTown4_EQR_720p_0015
#   ✓ CamdenTown4_EQR_720p_0016.mp4 -> CamdenTown4_EQR_720p_0016
#   ✓ CamdenTown4_EQR_720p_0017.mp4 -> CamdenTown4_EQR_720p_0017
#   ✓ CamdenTown4_EQR_720p_0018.mp4 -> CamdenTown4_EQR_720p_0018
#   ✓ CamdenTown4_EQR_720p_0019.mp4 -> CamdenTown4_EQR_720p_0019
#   ✓ CamdenTown4_EQR_720p_0020.mp4 -> CamdenTown4_EQR_720p_0020
#   ✓ CamdenTown4_EQR_720p_0021.mp4 -> CamdenTown4_EQR_720p_0021
#   ✓ CamdenTown4_EQR_720p_0022.mp4 -> CamdenTown4_EQR_720p_0022
#   ✓ CamdenTown4_EQR_720p_0023.mp4 -> CamdenTown4_EQR_720p_0023
#   ✓ CamdenTown4_EQR_720p_0024.mp4 -> CamdenTown4_EQR_720p_0024
#   ✓ CamdenTown4_EQR_720p_0025.mp4 -> CamdenTown4_EQR_720p_0025
#   ✓ CamdenTown4_EQR_720p_0026.mp4 -> CamdenTown4_EQR_720p_0026
#   ✓ CamdenTown4_EQR_720p_0027.mp4 -> CamdenTown4_EQR_720p_0027
#   ✓ CamdenTown4_EQR_720p_0028.mp4 -> CamdenTown4_EQR_720p_0028
#   ✓ CamdenTown4_EQR_720p_0029.mp4 -> CamdenTown4_EQR_720p_0029
#   ✓ CamdenTown4_EQR_720p_0030.mp4 -> CamdenTown4_EQR_720p_0030
#   ✓ CamdenTown4_EQR_720p_0031.mp4 -> CamdenTown4_EQR_720p_0031
#   ✓ CamdenTown4_EQR_720p_0032.mp4 -> CamdenTown4_EQR_720p_0032
#   ✓ CamdenTown4_EQR_720p_0033.mp4 -> CamdenTown4_EQR_720p_0033
#   ✓ CamdenTown4_EQR_720p_0034.mp4 -> CamdenTown4_EQR_720p_0034
#   ✓ CamdenTown4_EQR_720p_0035.mp4 -> CamdenTown4_EQR_720p_0035
#   ✓ CamdenTown4_EQR_720p_0036.mp4 -> CamdenTown4_EQR_720p_0036
#   ✓ CamdenTown4_EQR_720p_0037.mp4 -> CamdenTown4_EQR_720p_0037
#   ✓ CamdenTown4_EQR_720p_0038.mp4 -> CamdenTown4_EQR_720p_0038
#   ✓ CamdenTown4_EQR_720p_0039.mp4 -> CamdenTown4_EQR_720p_0039
#   ✓ CamdenTown4_EQR_720p_0040.mp4 -> CamdenTown4_EQR_720p_0040
#   ✓ CamdenTown4_EQR_720p_0041.mp4 -> CamdenTown4_EQR_720p_0041
#   ✓ CamdenTown4_EQR_720p_0042.mp4 -> CamdenTown4_EQR_720p_0042
#   ✓ CamdenTown4_EQR_720p_0043.mp4 -> CamdenTown4_EQR_720p_0043
#   ✓ CamdenTown4_EQR_720p_0044.mp4 -> CamdenTown4_EQR_720p_0044
#   ✓ CamdenTown4_EQR_720p_0045.mp4 -> CamdenTown4_EQR_720p_0045
#   ✓ CamdenTown4_EQR_720p_0046.mp4 -> CamdenTown4_EQR_720p_0046
#   ✓ CamdenTown4_EQR_720p_0047.mp4 -> CamdenTown4_EQR_720p_0047
#   ✓ CamdenTown4_EQR_720p_0048.mp4 -> CamdenTown4_EQR_720p_0048
#   ✓ CamdenTown4_EQR_720p_0049.mp4 -> CamdenTown4_EQR_720p_0049
#   ✓ CamdenTown4_EQR_720p_0050.mp4 -> CamdenTown4_EQR_720p_0050
#   ✓ CamdenTown4_EQR_720p_0051.mp4 -> CamdenTown4_EQR_720p_0051
#   ✓ CamdenTown4_EQR_720p_0052.mp4 -> CamdenTown4_EQR_720p_0052
#   ✓ CamdenTown4_EQR_720p_0053.mp4 -> CamdenTown4_EQR_720p_0053
#   ✓ CamdenTown4_EQR_720p_0054.mp4 -> CamdenTown4_EQR_720p_0054
#   ✓ CamdenTown4_EQR_720p_0055.mp4 -> CamdenTown4_EQR_720p_0055
#   ✓ CamdenTown4_EQR_720p_0056.mp4 -> CamdenTown4_EQR_720p_0056
#   ✓ CamdenTown4_EQR_720p_0057.mp4 -> CamdenTown4_EQR_720p_0057
#   ✓ CamdenTown4_EQR_720p_0058.mp4 -> CamdenTown4_EQR_720p_0058
#   ✓ CamdenTown4_EQR_720p_0059.mp4 -> CamdenTown4_EQR_720p_0059
#   ✓ CamdenTown4_EQR_720p_0060.mp4 -> CamdenTown4_EQR_720p_0060
#   ✓ CamdenTown4_EQR_720p_0061.mp4 -> CamdenTown4_EQR_720p_0061
#   ✓ CamdenTown4_EQR_720p_0062.mp4 -> CamdenTown4_EQR_720p_0062
#   ✓ CamdenTown4_EQR_720p_0063.mp4 -> CamdenTown4_EQR_720p_0063
#   ✓ CamdenTown4_EQR_720p_0064.mp4 -> CamdenTown4_EQR_720p_0064
#   ✓ CamdenTown4_EQR_720p_0065.mp4 -> CamdenTown4_EQR_720p_0065
#   ✓ CamdenTown4_EQR_720p_0066.mp4 -> CamdenTown4_EQR_720p_0066
#   ✓ CamdenTown4_EQR_720p_0067.mp4 -> CamdenTown4_EQR_720p_0067
#   ✓ CamdenTown4_EQR_720p_0068.mp4 -> CamdenTown4_EQR_720p_0068
#   ✓ CamdenTown4_EQR_720p_0069.mp4 -> CamdenTown4_EQR_720p_0069
#   ✓ CamdenTown4_EQR_720p_0070.mp4 -> CamdenTown4_EQR_720p_0070
#   ✓ CamdenTown4_EQR_720p_0071.mp4 -> CamdenTown4_EQR_720p_0071
#   ✓ CamdenTown4_EQR_720p_0072.mp4 -> CamdenTown4_EQR_720p_0072
#   ✓ CamdenTown4_EQR_720p_0073.mp4 -> CamdenTown4_EQR_720p_0073
#   ✓ CamdenTown4_EQR_720p_0074.mp4 -> CamdenTown4_EQR_720p_0074
#   ✓ CamdenTown4_EQR_720p_0075.mp4 -> CamdenTown4_EQR_720p_0075
#   ✓ CamdenTown4_EQR_720p_0076.mp4 -> CamdenTown4_EQR_720p_0076
#   ✓ CamdenTown4_EQR_720p_0077.mp4 -> CamdenTown4_EQR_720p_0077
#   ✓ CamdenTown4_EQR_720p_0078.mp4 -> CamdenTown4_EQR_720p_0078
#   ✓ CamdenTown4_EQR_720p_0079.mp4 -> CamdenTown4_EQR_720p_0079
#   ✓ CamdenTown4_EQR_720p_0080.mp4 -> CamdenTown4_EQR_720p_0080
#   ✓ CamdenTown4_EQR_720p_0081.mp4 -> CamdenTown4_EQR_720p_0081
#   ✓ CamdenTown4_EQR_720p_0082.mp4 -> CamdenTown4_EQR_720p_0082
#   ✓ CamdenTown4_EQR_720p_0083.mp4 -> CamdenTown4_EQR_720p_0083
#   ✓ CamdenTown4_EQR_720p_0084.mp4 -> CamdenTown4_EQR_720p_0084
#   ✓ CamdenTown4_EQR_720p_0085.mp4 -> CamdenTown4_EQR_720p_0085
#   ✓ CamdenTown4_EQR_720p_0086.mp4 -> CamdenTown4_EQR_720p_0086
#   ✓ CamdenTown4_EQR_720p_0087.mp4 -> CamdenTown4_EQR_720p_0087
#   ✓ CamdenTown4_EQR_720p_0088.mp4 -> CamdenTown4_EQR_720p_0088
#   ✓ CamdenTown4_EQR_720p_0089.mp4 -> CamdenTown4_EQR_720p_0089
#   ✓ CamdenTown4_EQR_720p_0090.mp4 -> CamdenTown4_EQR_720p_0090
#   ✓ EustonTap1_EQR_720p_0002.mp4 -> EustonTap1_EQR_720p_0002
#   ✓ EustonTap1_EQR_720p_0003.mp4 -> EustonTap1_EQR_720p_0003
#   ✓ EustonTap1_EQR_720p_0004.mp4 -> EustonTap1_EQR_720p_0004
#   ✓ EustonTap1_EQR_720p_0005.mp4 -> EustonTap1_EQR_720p_0005
#   ✓ EustonTap1_EQR_720p_0006.mp4 -> EustonTap1_EQR_720p_0006
#   ✓ EustonTap1_EQR_720p_0007.mp4 -> EustonTap1_EQR_720p_0007
#   ✓ EustonTap1_EQR_720p_0008.mp4 -> EustonTap1_EQR_720p_0008
#   ✓ EustonTap1_EQR_720p_0009.mp4 -> EustonTap1_EQR_720p_0009
#   ✓ EustonTap1_EQR_720p_0010.mp4 -> EustonTap1_EQR_720p_0010
#   ✓ EustonTap1_EQR_720p_0011.mp4 -> EustonTap1_EQR_720p_0011
#   ✓ EustonTap1_EQR_720p_0012.mp4 -> EustonTap1_EQR_720p_0012
#   ✓ EustonTap1_EQR_720p_0013.mp4 -> EustonTap1_EQR_720p_0013
#   ✓ EustonTap1_EQR_720p_0014.mp4 -> EustonTap1_EQR_720p_0014
#   ✓ EustonTap1_EQR_720p_0015.mp4 -> EustonTap1_EQR_720p_0015
#   ✓ EustonTap1_EQR_720p_0016.mp4 -> EustonTap1_EQR_720p_0016
#   ✓ EustonTap1_EQR_720p_0017.mp4 -> EustonTap1_EQR_720p_0017
#   ✓ EustonTap1_EQR_720p_0018.mp4 -> EustonTap1_EQR_720p_0018
#   ✓ EustonTap1_EQR_720p_0019.mp4 -> EustonTap1_EQR_720p_0019
#   ✓ EustonTap1_EQR_720p_0020.mp4 -> EustonTap1_EQR_720p_0020
#   ✓ EustonTap1_EQR_720p_0021.mp4 -> EustonTap1_EQR_720p_0021
#   ✓ EustonTap1_EQR_720p_0022.mp4 -> EustonTap1_EQR_720p_0022
#   ✓ EustonTap1_EQR_720p_0023.mp4 -> EustonTap1_EQR_720p_0023
#   ✓ EustonTap1_EQR_720p_0024.mp4 -> EustonTap1_EQR_720p_0024
#   ✓ EustonTap1_EQR_720p_0025.mp4 -> EustonTap1_EQR_720p_0025
#   ✓ EustonTap1_EQR_720p_0026.mp4 -> EustonTap1_EQR_720p_0026
#   ✓ EustonTap1_EQR_720p_0027.mp4 -> EustonTap1_EQR_720p_0027
#   ✓ EustonTap1_EQR_720p_0028.mp4 -> EustonTap1_EQR_720p_0028
#   ✓ EustonTap1_EQR_720p_0029.mp4 -> EustonTap1_EQR_720p_0029
#   ✓ EustonTap1_EQR_720p_0030.mp4 -> EustonTap1_EQR_720p_0030
#   ✓ EustonTap1_EQR_720p_0031.mp4 -> EustonTap1_EQR_720p_0031
#   ✓ EustonTap1_EQR_720p_0032.mp4 -> EustonTap1_EQR_720p_0032
#   ✓ EustonTap1_EQR_720p_0033.mp4 -> EustonTap1_EQR_720p_0033
#   ✓ EustonTap1_EQR_720p_0034.mp4 -> EustonTap1_EQR_720p_0034
#   ✓ EustonTap1_EQR_720p_0035.mp4 -> EustonTap1_EQR_720p_0035
#   ✓ EustonTap1_EQR_720p_0036.mp4 -> EustonTap1_EQR_720p_0036
#   ✓ EustonTap1_EQR_720p_0037.mp4 -> EustonTap1_EQR_720p_0037
#   ✓ EustonTap1_EQR_720p_0038.mp4 -> EustonTap1_EQR_720p_0038
#   ✓ EustonTap1_EQR_720p_0039.mp4 -> EustonTap1_EQR_720p_0039
#   ✓ EustonTap1_EQR_720p_0040.mp4 -> EustonTap1_EQR_720p_0040
#   ✓ EustonTap1_EQR_720p_0041.mp4 -> EustonTap1_EQR_720p_0041
#   ✓ EustonTap1_EQR_720p_0042.mp4 -> EustonTap1_EQR_720p_0042
#   ✓ EustonTap1_EQR_720p_0043.mp4 -> EustonTap1_EQR_720p_0043
#   ✓ EustonTap1_EQR_720p_0044.mp4 -> EustonTap1_EQR_720p_0044
#   ✓ EustonTap1_EQR_720p_0045.mp4 -> EustonTap1_EQR_720p_0045
#   ✓ EustonTap1_EQR_720p_0046.mp4 -> EustonTap1_EQR_720p_0046
#   ✓ EustonTap1_EQR_720p_0047.mp4 -> EustonTap1_EQR_720p_0047
#   ✓ EustonTap1_EQR_720p_0048.mp4 -> EustonTap1_EQR_720p_0048
#   ✓ EustonTap1_EQR_720p_0049.mp4 -> EustonTap1_EQR_720p_0049
#   ✓ EustonTap1_EQR_720p_0050.mp4 -> EustonTap1_EQR_720p_0050
#   ✓ EustonTap1_EQR_720p_0051.mp4 -> EustonTap1_EQR_720p_0051
#   ✓ EustonTap1_EQR_720p_0052.mp4 -> EustonTap1_EQR_720p_0052
#   ✓ EustonTap1_EQR_720p_0053.mp4 -> EustonTap1_EQR_720p_0053
#   ✓ EustonTap1_EQR_720p_0054.mp4 -> EustonTap1_EQR_720p_0054
#   ✓ EustonTap1_EQR_720p_0055.mp4 -> EustonTap1_EQR_720p_0055
#   ✓ EustonTap1_EQR_720p_0056.mp4 -> EustonTap1_EQR_720p_0056
#   ✓ EustonTap1_EQR_720p_0057.mp4 -> EustonTap1_EQR_720p_0057
#   ✓ EustonTap1_EQR_720p_0058.mp4 -> EustonTap1_EQR_720p_0058
#   ✓ EustonTap1_EQR_720p_0059.mp4 -> EustonTap1_EQR_720p_0059
#   ✓ EustonTap1_EQR_720p_0060.mp4 -> EustonTap1_EQR_720p_0060
#   ✓ EustonTap1_EQR_720p_0061.mp4 -> EustonTap1_EQR_720p_0061
#   ✓ EustonTap1_EQR_720p_0062.mp4 -> EustonTap1_EQR_720p_0062
#   ✓ EustonTap1_EQR_720p_0063.mp4 -> EustonTap1_EQR_720p_0063
#   ✓ EustonTap1_EQR_720p_0064.mp4 -> EustonTap1_EQR_720p_0064
#   ✓ EustonTap1_EQR_720p_0065.mp4 -> EustonTap1_EQR_720p_0065
#   ✓ EustonTap1_EQR_720p_0066.mp4 -> EustonTap1_EQR_720p_0066
#   ✓ EustonTap1_EQR_720p_0067.mp4 -> EustonTap1_EQR_720p_0067
#   ✓ EustonTap1_EQR_720p_0068.mp4 -> EustonTap1_EQR_720p_0068
#   ✓ EustonTap1_EQR_720p_0069.mp4 -> EustonTap1_EQR_720p_0069
#   ✓ EustonTap1_EQR_720p_0070.mp4 -> EustonTap1_EQR_720p_0070
#   ✓ EustonTap1_EQR_720p_0071.mp4 -> EustonTap1_EQR_720p_0071
#   ✓ EustonTap1_EQR_720p_0072.mp4 -> EustonTap1_EQR_720p_0072
#   ✓ EustonTap1_EQR_720p_0073.mp4 -> EustonTap1_EQR_720p_0073
#   ✓ EustonTap1_EQR_720p_0074.mp4 -> EustonTap1_EQR_720p_0074
#   ✓ EustonTap1_EQR_720p_0075.mp4 -> EustonTap1_EQR_720p_0075
#   ✓ EustonTap1_EQR_720p_0076.mp4 -> EustonTap1_EQR_720p_0076
#   ✓ EustonTap1_EQR_720p_0077.mp4 -> EustonTap1_EQR_720p_0077
#   ✓ EustonTap1_EQR_720p_0078.mp4 -> EustonTap1_EQR_720p_0078
#   ✓ EustonTap1_EQR_720p_0079.mp4 -> EustonTap1_EQR_720p_0079
#   ✓ EustonTap1_EQR_720p_0080.mp4 -> EustonTap1_EQR_720p_0080
#   ✓ EustonTap1_EQR_720p_0081.mp4 -> EustonTap1_EQR_720p_0081
#   ✓ EustonTap1_EQR_720p_0082.mp4 -> EustonTap1_EQR_720p_0082
#   ✓ EustonTap1_EQR_720p_0083.mp4 -> EustonTap1_EQR_720p_0083
#   ✓ EustonTap1_EQR_720p_0084.mp4 -> EustonTap1_EQR_720p_0084
#   ✓ EustonTap1_EQR_720p_0085.mp4 -> EustonTap1_EQR_720p_0085
#   ✓ EustonTap1_EQR_720p_0086.mp4 -> EustonTap1_EQR_720p_0086
#   ✓ EustonTap1_EQR_720p_0087.mp4 -> EustonTap1_EQR_720p_0087
#   ✓ EustonTap1_EQR_720p_0088.mp4 -> EustonTap1_EQR_720p_0088
#   ✓ EustonTap1_EQR_720p_0089.mp4 -> EustonTap1_EQR_720p_0089
#   ✓ EustonTap1_EQR_720p_0090.mp4 -> EustonTap1_EQR_720p_0090
#   ✓ EustonTap1_EQR_720p_0091.mp4 -> EustonTap1_EQR_720p_0091
#   ✓ EustonTap2_EQR_720p_0002.mp4 -> EustonTap2_EQR_720p_0002
#   ✓ EustonTap2_EQR_720p_0003.mp4 -> EustonTap2_EQR_720p_0003
#   ✓ EustonTap2_EQR_720p_0004.mp4 -> EustonTap2_EQR_720p_0004
#   ✓ EustonTap2_EQR_720p_0005.mp4 -> EustonTap2_EQR_720p_0005
#   ✓ EustonTap2_EQR_720p_0006.mp4 -> EustonTap2_EQR_720p_0006
#   ✓ EustonTap2_EQR_720p_0007.mp4 -> EustonTap2_EQR_720p_0007
#   ✓ EustonTap2_EQR_720p_0008.mp4 -> EustonTap2_EQR_720p_0008
#   ✓ EustonTap2_EQR_720p_0009.mp4 -> EustonTap2_EQR_720p_0009
#   ✓ EustonTap2_EQR_720p_0010.mp4 -> EustonTap2_EQR_720p_0010
#   ✓ EustonTap2_EQR_720p_0011.mp4 -> EustonTap2_EQR_720p_0011
#   ✓ EustonTap2_EQR_720p_0012.mp4 -> EustonTap2_EQR_720p_0012
#   ✓ EustonTap2_EQR_720p_0013.mp4 -> EustonTap2_EQR_720p_0013
#   ✓ EustonTap2_EQR_720p_0014.mp4 -> EustonTap2_EQR_720p_0014
#   ✓ EustonTap2_EQR_720p_0015.mp4 -> EustonTap2_EQR_720p_0015
#   ✓ EustonTap2_EQR_720p_0016.mp4 -> EustonTap2_EQR_720p_0016
#   ✓ EustonTap2_EQR_720p_0017.mp4 -> EustonTap2_EQR_720p_0017
#   ✓ EustonTap2_EQR_720p_0018.mp4 -> EustonTap2_EQR_720p_0018
#   ✓ EustonTap2_EQR_720p_0019.mp4 -> EustonTap2_EQR_720p_0019
#   ✓ EustonTap2_EQR_720p_0020.mp4 -> EustonTap2_EQR_720p_0020
#   ✓ EustonTap2_EQR_720p_0021.mp4 -> EustonTap2_EQR_720p_0021
#   ✓ EustonTap2_EQR_720p_0022.mp4 -> EustonTap2_EQR_720p_0022
#   ✓ EustonTap2_EQR_720p_0023.mp4 -> EustonTap2_EQR_720p_0023
#   ✓ EustonTap2_EQR_720p_0024.mp4 -> EustonTap2_EQR_720p_0024
#   ✓ EustonTap2_EQR_720p_0025.mp4 -> EustonTap2_EQR_720p_0025
#   ✓ EustonTap2_EQR_720p_0026.mp4 -> EustonTap2_EQR_720p_0026
#   ✓ EustonTap2_EQR_720p_0027.mp4 -> EustonTap2_EQR_720p_0027
#   ✓ EustonTap2_EQR_720p_0028.mp4 -> EustonTap2_EQR_720p_0028
#   ✓ EustonTap2_EQR_720p_0029.mp4 -> EustonTap2_EQR_720p_0029
#   ✓ EustonTap2_EQR_720p_0030.mp4 -> EustonTap2_EQR_720p_0030
#   ✓ EustonTap2_EQR_720p_0031.mp4 -> EustonTap2_EQR_720p_0031
#   ✓ EustonTap2_EQR_720p_0032.mp4 -> EustonTap2_EQR_720p_0032
#   ✓ EustonTap2_EQR_720p_0033.mp4 -> EustonTap2_EQR_720p_0033
#   ✓ EustonTap2_EQR_720p_0034.mp4 -> EustonTap2_EQR_720p_0034
#   ✓ EustonTap2_EQR_720p_0035.mp4 -> EustonTap2_EQR_720p_0035
#   ✓ EustonTap2_EQR_720p_0036.mp4 -> EustonTap2_EQR_720p_0036
#   ✓ EustonTap2_EQR_720p_0037.mp4 -> EustonTap2_EQR_720p_0037
#   ✓ EustonTap2_EQR_720p_0038.mp4 -> EustonTap2_EQR_720p_0038
#   ✓ EustonTap2_EQR_720p_0039.mp4 -> EustonTap2_EQR_720p_0039
#   ✓ EustonTap2_EQR_720p_0040.mp4 -> EustonTap2_EQR_720p_0040
#   ✓ EustonTap2_EQR_720p_0041.mp4 -> EustonTap2_EQR_720p_0041
#   ✓ EustonTap2_EQR_720p_0042.mp4 -> EustonTap2_EQR_720p_0042
#   ✓ EustonTap2_EQR_720p_0043.mp4 -> EustonTap2_EQR_720p_0043
#   ✓ EustonTap2_EQR_720p_0044.mp4 -> EustonTap2_EQR_720p_0044
#   ✓ EustonTap2_EQR_720p_0045.mp4 -> EustonTap2_EQR_720p_0045
#   ✓ EustonTap2_EQR_720p_0046.mp4 -> EustonTap2_EQR_720p_0046
#   ✓ EustonTap2_EQR_720p_0047.mp4 -> EustonTap2_EQR_720p_0047
#   ✓ EustonTap2_EQR_720p_0048.mp4 -> EustonTap2_EQR_720p_0048
#   ✓ EustonTap2_EQR_720p_0049.mp4 -> EustonTap2_EQR_720p_0049
#   ✓ EustonTap2_EQR_720p_0050.mp4 -> EustonTap2_EQR_720p_0050
#   ✓ EustonTap2_EQR_720p_0051.mp4 -> EustonTap2_EQR_720p_0051
#   ✓ EustonTap2_EQR_720p_0052.mp4 -> EustonTap2_EQR_720p_0052
#   ✓ EustonTap2_EQR_720p_0053.mp4 -> EustonTap2_EQR_720p_0053
#   ✓ EustonTap2_EQR_720p_0054.mp4 -> EustonTap2_EQR_720p_0054
#   ✓ EustonTap2_EQR_720p_0055.mp4 -> EustonTap2_EQR_720p_0055
#   ✓ EustonTap2_EQR_720p_0056.mp4 -> EustonTap2_EQR_720p_0056
#   ✓ EustonTap2_EQR_720p_0057.mp4 -> EustonTap2_EQR_720p_0057
#   ✓ EustonTap2_EQR_720p_0058.mp4 -> EustonTap2_EQR_720p_0058
#   ✓ EustonTap2_EQR_720p_0059.mp4 -> EustonTap2_EQR_720p_0059
#   ✓ EustonTap2_EQR_720p_0060.mp4 -> EustonTap2_EQR_720p_0060
#   ✓ EustonTap2_EQR_720p_0061.mp4 -> EustonTap2_EQR_720p_0061
#   ✓ EustonTap2_EQR_720p_0062.mp4 -> EustonTap2_EQR_720p_0062
#   ✓ EustonTap2_EQR_720p_0063.mp4 -> EustonTap2_EQR_720p_0063
#   ✓ EustonTap2_EQR_720p_0064.mp4 -> EustonTap2_EQR_720p_0064
#   ✓ EustonTap2_EQR_720p_0065.mp4 -> EustonTap2_EQR_720p_0065
#   ✓ EustonTap2_EQR_720p_0066.mp4 -> EustonTap2_EQR_720p_0066
#   ✓ EustonTap2_EQR_720p_0067.mp4 -> EustonTap2_EQR_720p_0067
#   ✓ EustonTap2_EQR_720p_0068.mp4 -> EustonTap2_EQR_720p_0068
#   ✓ EustonTap2_EQR_720p_0069.mp4 -> EustonTap2_EQR_720p_0069
#   ✓ EustonTap2_EQR_720p_0070.mp4 -> EustonTap2_EQR_720p_0070
#   ✓ EustonTap2_EQR_720p_0071.mp4 -> EustonTap2_EQR_720p_0071
#   ✓ EustonTap2_EQR_720p_0072.mp4 -> EustonTap2_EQR_720p_0072
#   ✓ EustonTap2_EQR_720p_0073.mp4 -> EustonTap2_EQR_720p_0073
#   ✓ EustonTap2_EQR_720p_0074.mp4 -> EustonTap2_EQR_720p_0074
#   ✓ EustonTap2_EQR_720p_0075.mp4 -> EustonTap2_EQR_720p_0075
#   ✓ EustonTap2_EQR_720p_0076.mp4 -> EustonTap2_EQR_720p_0076
#   ✓ EustonTap2_EQR_720p_0077.mp4 -> EustonTap2_EQR_720p_0077
#   ✓ EustonTap2_EQR_720p_0078.mp4 -> EustonTap2_EQR_720p_0078
#   ✓ EustonTap2_EQR_720p_0079.mp4 -> EustonTap2_EQR_720p_0079
#   ✓ EustonTap2_EQR_720p_0080.mp4 -> EustonTap2_EQR_720p_0080
#   ✓ EustonTap2_EQR_720p_0081.mp4 -> EustonTap2_EQR_720p_0081
#   ✓ EustonTap2_EQR_720p_0082.mp4 -> EustonTap2_EQR_720p_0082
#   ✓ EustonTap2_EQR_720p_0083.mp4 -> EustonTap2_EQR_720p_0083
#   ✓ EustonTap2_EQR_720p_0084.mp4 -> EustonTap2_EQR_720p_0084
#   ✓ EustonTap2_EQR_720p_0085.mp4 -> EustonTap2_EQR_720p_0085
#   ✓ EustonTap2_EQR_720p_0086.mp4 -> EustonTap2_EQR_720p_0086
#   ✓ EustonTap2_EQR_720p_0087.mp4 -> EustonTap2_EQR_720p_0087
#   ✓ EustonTap3_0347_0011.mp4 -> EustonTap3_0347_0011
#   ✓ EustonTap3_0347_0012.mp4 -> EustonTap3_0347_0012
#   ✓ EustonTap3_0347_0013.mp4 -> EustonTap3_0347_0013
#   ✓ EustonTap3_0347_0014.mp4 -> EustonTap3_0347_0014
#   ✓ EustonTap3_0347_0015.mp4 -> EustonTap3_0347_0015
#   ✓ EustonTap3_0347_0016.mp4 -> EustonTap3_0347_0016
#   ✓ EustonTap3_0347_0017.mp4 -> EustonTap3_0347_0017
#   ✓ EustonTap3_0347_0018.mp4 -> EustonTap3_0347_0018
#   ✓ EustonTap3_0347_0019.mp4 -> EustonTap3_0347_0019
#   ✓ EustonTap3_0347_0020.mp4 -> EustonTap3_0347_0020
#   ✓ EustonTap3_0347_0021.mp4 -> EustonTap3_0347_0021
#   ✓ EustonTap3_0347_0022.mp4 -> EustonTap3_0347_0022
#   ✓ EustonTap3_0347_0023.mp4 -> EustonTap3_0347_0023
#   ✓ EustonTap3_0347_0024.mp4 -> EustonTap3_0347_0024
#   ✓ EustonTap3_0347_0025.mp4 -> EustonTap3_0347_0025
#   ✓ MarchmontGarden1_EQR_720p_0045.mp4 -> MarchmontGarden1_EQR_720p_0045
#   ✓ MarchmontGarden1_EQR_720p_0046.mp4 -> MarchmontGarden1_EQR_720p_0046
#   ✓ MarchmontGarden1_EQR_720p_0047.mp4 -> MarchmontGarden1_EQR_720p_0047
#   ✓ MarchmontGarden1_EQR_720p_0048.mp4 -> MarchmontGarden1_EQR_720p_0048
#   ✓ MarchmontGarden1_EQR_720p_0049.mp4 -> MarchmontGarden1_EQR_720p_0049
#   ✓ MarchmontGarden1_EQR_720p_0050.mp4 -> MarchmontGarden1_EQR_720p_0050
#   ✓ MarchmontGarden1_EQR_720p_0051.mp4 -> MarchmontGarden1_EQR_720p_0051
#   ✓ MarchmontGarden1_EQR_720p_0052.mp4 -> MarchmontGarden1_EQR_720p_0052
#   ✓ MarchmontGarden1_EQR_720p_0053.mp4 -> MarchmontGarden1_EQR_720p_0053
#   ✓ MarchmontGarden1_EQR_720p_0054.mp4 -> MarchmontGarden1_EQR_720p_0054
#   ✓ MarchmontGarden1_EQR_720p_0055.mp4 -> MarchmontGarden1_EQR_720p_0055
#   ✓ MarchmontGarden1_EQR_720p_0056.mp4 -> MarchmontGarden1_EQR_720p_0056
#   ✓ MarchmontGarden1_EQR_720p_0057.mp4 -> MarchmontGarden1_EQR_720p_0057
#   ✓ MarchmontGarden1_EQR_720p_0058.mp4 -> MarchmontGarden1_EQR_720p_0058
#   ✓ MarchmontGarden1_EQR_720p_0059.mp4 -> MarchmontGarden1_EQR_720p_0059
#   ✓ MarchmontGarden1_EQR_720p_0060.mp4 -> MarchmontGarden1_EQR_720p_0060
#   ✓ MarchmontGarden1_EQR_720p_0061.mp4 -> MarchmontGarden1_EQR_720p_0061
#   ✓ MarchmontGarden1_EQR_720p_0062.mp4 -> MarchmontGarden1_EQR_720p_0062
#   ✓ MarchmontGarden1_EQR_720p_0063.mp4 -> MarchmontGarden1_EQR_720p_0063
#   ✓ MarchmontGarden1_EQR_720p_0064.mp4 -> MarchmontGarden1_EQR_720p_0064
#   ✓ MarchmontGarden1_EQR_720p_0065.mp4 -> MarchmontGarden1_EQR_720p_0065
#   ✓ MarchmontGarden1_EQR_720p_0066.mp4 -> MarchmontGarden1_EQR_720p_0066
#   ✓ MarchmontGarden1_EQR_720p_0067.mp4 -> MarchmontGarden1_EQR_720p_0067
#   ✓ MarchmontGarden1_EQR_720p_0068.mp4 -> MarchmontGarden1_EQR_720p_0068
#   ✓ MarchmontGarden1_EQR_720p_0069.mp4 -> MarchmontGarden1_EQR_720p_0069
#   ✓ MarchmontGarden1_EQR_720p_0070.mp4 -> MarchmontGarden1_EQR_720p_0070
#   ✓ MarchmontGarden1_EQR_720p_0071.mp4 -> MarchmontGarden1_EQR_720p_0071
#   ✓ MarchmontGarden1_EQR_720p_0072.mp4 -> MarchmontGarden1_EQR_720p_0072
#   ✓ MarchmontGarden1_EQR_720p_0073.mp4 -> MarchmontGarden1_EQR_720p_0073
#   ✓ MarchmontGarden1_EQR_720p_0074.mp4 -> MarchmontGarden1_EQR_720p_0074
#   ✓ TorringtonSq4_EQR_720p_0066.mp4 -> TorringtonSq4_EQR_720p_0066
#   ✓ TorringtonSq4_EQR_720p_0067.mp4 -> TorringtonSq4_EQR_720p_0067
#   ✓ TorringtonSq4_EQR_720p_0068.mp4 -> TorringtonSq4_EQR_720p_0068
#   ✓ TorringtonSq4_EQR_720p_0069.mp4 -> TorringtonSq4_EQR_720p_0069
#   ✓ TorringtonSq4_EQR_720p_0070.mp4 -> TorringtonSq4_EQR_720p_0070
#   ✓ TorringtonSq4_EQR_720p_0071.mp4 -> TorringtonSq4_EQR_720p_0071
#   ✓ TorringtonSq4_EQR_720p_0072.mp4 -> TorringtonSq4_EQR_720p_0072
#   ✓ TorringtonSq4_EQR_720p_0073.mp4 -> TorringtonSq4_EQR_720p_0073
#   ✓ TorringtonSq4_EQR_720p_0074.mp4 -> TorringtonSq4_EQR_720p_0074
#   ✓ TorringtonSq4_EQR_720p_0075.mp4 -> TorringtonSq4_EQR_720p_0075
#   ✓ TorringtonSq4_EQR_720p_0076.mp4 -> TorringtonSq4_EQR_720p_0076
#   ✓ TorringtonSq4_EQR_720p_0077.mp4 -> TorringtonSq4_EQR_720p_0077
#   ✓ TorringtonSq4_EQR_720p_0078.mp4 -> TorringtonSq4_EQR_720p_0078
#   ✓ TorringtonSq4_EQR_720p_0079.mp4 -> TorringtonSq4_EQR_720p_0079
#   ✓ TorringtonSq4_EQR_720p_0080.mp4 -> TorringtonSq4_EQR_720p_0080
#   ✓ TorringtonSq4_EQR_720p_0081.mp4 -> TorringtonSq4_EQR_720p_0081
#   ✓ TorringtonSq4_EQR_720p_0082.mp4 -> TorringtonSq4_EQR_720p_0082
#   ✓ TorringtonSq4_EQR_720p_0083.mp4 -> TorringtonSq4_EQR_720p_0083
#   ✓ TorringtonSq4_EQR_720p_0084.mp4 -> TorringtonSq4_EQR_720p_0084
#   ✓ TorringtonSq4_EQR_720p_0085.mp4 -> TorringtonSq4_EQR_720p_0085
#   ✓ TorringtonSq4_EQR_720p_0086.mp4 -> TorringtonSq4_EQR_720p_0086
#   ✓ TorringtonSq4_EQR_720p_0087.mp4 -> TorringtonSq4_EQR_720p_0087
# ✅ TSV file created at ./training/video_train_stride_10.tsv
# Total videos processed: 2692
# Total labels assigned: 2692
#
# 📄 TSV:
#                             id             label
# 0  CamdenMarket1_EQR_720p_0000  audio from video
# 1  CamdenMarket1_EQR_720p_0001  audio from video
# 2  CamdenMarket1_EQR_720p_0002  audio from video
# 3  CamdenMarket1_EQR_720p_0003  audio from video
# 4  CamdenMarket1_EQR_720p_0004  audio from video

# %% [markdown]
# ## Download checkpoints and ext-weights

# %%
# MMAudio Model Download with Mirror Support - Jupyter Notebook
# 使用镜像源下载模型文件

# Cell 1: 设置镜像环境
print("🌐 Setting up mirror environment for China users")
print("=" * 50)

import os
import subprocess
from pathlib import Path

# 设置环境变量使用镜像
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
print("✅ Set HF_ENDPOINT to: https://hf-mirror.com")

# 也可以设置其他镜像选项
mirror_options = {
    'HF_ENDPOINT': 'https://hf-mirror.com',
    'HF_HUB_DISABLE_TELEMETRY': '1',
    'HF_HUB_CACHE': str(Path.home() / '.cache' / 'huggingface'),
    'CURL_TIMEOUT': '300'  # 5分钟超时
}

for key, value in mirror_options.items():
    os.environ[key] = value
    print(f"   {key} = {value}")

print("\n🔧 Testing mirror connectivity...")
test_result = subprocess.run(['curl', '-I', 'https://hf-mirror.com'], 
                           capture_output=True, text=True, timeout=10)
if test_result.returncode == 0:
    print("✅ Mirror connection successful!")
else:
    print("⚠️  Mirror connection test failed, but proceeding...")

# Cell 2: 创建目录和定义文件
print("\n📁 Creating directories...")

# Create directories
ext_weights_dir = Path("ext_weights")
weights_dir = Path("weights")

ext_weights_dir.mkdir(exist_ok=True)
weights_dir.mkdir(exist_ok=True)

print(f"   • ext_weights: {ext_weights_dir}")
print(f"   • weights: {weights_dir}")

# 使用镜像源的URL
mirror_base_url = "https://hf-mirror.com/hkchengrex/MMAudio/resolve/main"

small_model_files = {
    f'{ext_weights_dir}/v1-16.pth': f'{mirror_base_url}/ext_weights/v1-16.pth',
    f'{ext_weights_dir}/synchformer_state_dict.pth': f'{mirror_base_url}/ext_weights/synchformer_state_dict.pth',
    f'{ext_weights_dir}/best_netG.pt': f'{mirror_base_url}/ext_weights/best_netG.pt',
    f'{weights_dir}/mmaudio_small_16k.pth': f'{mirror_base_url}/weights/mmaudio_small_16k.pth'
}

print(f"\n📦 Files to download from mirror:")
file_info = {
    'v1-16.pth': {'desc': 'VAE model for 16kHz', 'size_mb': 60},
    'synchformer_state_dict.pth': {'desc': 'Synchronization model', 'size_mb': 150},
    'best_netG.pt': {'desc': 'Vocoder model', 'size_mb': 40},
    'mmaudio_small_16k.pth': {'desc': 'MMAudio Small model', 'size_mb': 600}
}

for file_path, url in small_model_files.items():
    filename = Path(file_path).name
    info = file_info[filename]
    print(f"• {filename} ({info['size_mb']}MB)")
    print(f"  └─ {url}")

# Cell 3: 检查现有文件
print(f"\n🔍 Checking existing files...")
existing_files = []
missing_files = []

for file_path, url in small_model_files.items():
    path = Path(file_path)
    if path.exists() and path.stat().st_size > 1024*1024:
        size_mb = path.stat().st_size / (1024*1024)
        print(f"✅ {path.name} exists ({size_mb:.1f} MB)")
        existing_files.append(file_path)
    else:
        print(f"❌ {path.name} missing")
        missing_files.append(file_path)

if not missing_files:
    print("\n🎉 All files already downloaded!")

# Cell 4: 使用镜像下载
if missing_files:
    print(f"\n🚀 Downloading from mirror (hf-mirror.com)...")
    print("=" * 45)
    
    for file_path in missing_files:
        path = Path(file_path)
        filename = path.name
        url = small_model_files[file_path]
        info = file_info[filename]
        
        print(f"\n📥 Downloading {filename}")
        print(f"   📝 {info['desc']} (~{info['size_mb']}MB)")
        print(f"   🔗 {url}")
        
        # 确保父目录存在
        path.parent.mkdir(parents=True, exist_ok=True)
        
        # 使用curl下载，增加更多选项
        curl_command = [
            'curl', 
            '-L',                    # 跟随重定向
            '-o', str(path),         # 输出文件
            '--connect-timeout', '30', # 连接超时30秒
            '--max-time', '1200',    # 最大传输时间20分钟
            '--retry', '3',          # 重试3次
            '--retry-delay', '5',    # 重试间隔5秒
            '--progress-bar',        # 显示进度条
            url
        ]
        
        print(f"   ⏳ Starting download...")
        result = subprocess.run(curl_command)
        
        # 检查结果
        if result.returncode == 0 and path.exists():
            size_mb = path.stat().st_size / (1024*1024)
            if size_mb > 1:
                print(f"   ✅ Success! Downloaded {size_mb:.1f} MB")
            else:
                print(f"   ❌ File too small ({size_mb:.1f} MB) - may be corrupted")
        else:
            print(f"   ❌ Download failed (return code: {result.returncode})")
            
            # 如果失败，尝试其他镜像
            if result.returncode == 28:  # 超时错误
                print(f"   🔄 Timeout error, trying alternative method...")
                
                # 尝试分段下载
                alt_command = [
                    'curl', '-L', '-C', '-',  # 续传
                    '-o', str(path), 
                    '--connect-timeout', '60',
                    '--max-time', '3600',  # 1小时
                    '--retry', '5',
                    url
                ]
                
                alt_result = subprocess.run(alt_command)
                if alt_result.returncode == 0 and path.exists():
                    size_mb = path.stat().st_size / (1024*1024)
                    print(f"   ✅ Alternative download successful! {size_mb:.1f} MB")
                else:
                    print(f"   ❌ Alternative download also failed")

# Cell 5: 最终验证
print(f"\n🏁 Final Verification")
print("=" * 25)

success_count = 0
total_size_mb = 0

for file_path, url in small_model_files.items():
    path = Path(file_path)
    if path.exists() and path.stat().st_size > 1024*1024:
        size_mb = path.stat().st_size / (1024*1024)
        total_size_mb += size_mb
        print(f"✅ {path.name} ({size_mb:.1f} MB)")
        success_count += 1
    else:
        print(f"❌ {path.name} - missing or corrupted")

print(f"\n📊 Summary:")
print(f"   Success: {success_count}/{len(small_model_files)} files")
print(f"   Total size: {total_size_mb:.1f} MB")

if success_count == len(small_model_files):
    print(f"\n🎉 SUCCESS! All models downloaded")
    print(f"✅ Ready for feature extraction!")
else:
    print(f"\n⚠️  {len(small_model_files) - success_count} files still missing")

# Cell 6: 备用下载方法 (如果镜像也失败)
if success_count < len(small_model_files):
    print(f"\n🔧 Alternative Download Methods")
    print("-" * 30)
    
    print("If mirror download failed, try these alternatives:")
    print()
    print("1. 手动下载 (Manual Download):")
    print("   Visit https://hf-mirror.com/hkchengrex/MMAudio/tree/main")
    print("   Download files manually to correct directories")
    print()
    print("2. 使用代理 (Use Proxy):")
    print("   export https_proxy=http://your-proxy:port")
    print("   export http_proxy=http://your-proxy:port")
    print()
    print("3. 分段下载 (Resume Download):")
    
    for file_path, url in small_model_files.items():
        path = Path(file_path)
        if not (path.exists() and path.stat().st_size > 1024*1024):
            print(f"   curl -C - -L -o {file_path} \\")
            print(f"        {url}")
    
    print()
    print("4. 使用Python requests:")
    print("   (See next cell for Python download method)")

# Cell 7: Python备用下载方法
def python_download_fallback():
    """使用Python requests作为备用下载方法"""
    import requests
    from tqdm import tqdm
    
    print("🐍 Python Download Fallback Method")
    print("-" * 35)
    
    for file_path, url in small_model_files.items():
        path = Path(file_path)
        if path.exists() and path.stat().st_size > 1024*1024:
            continue  # 跳过已下载的文件
            
        filename = path.name
        print(f"\n📥 Trying Python download: {filename}")
        
        try:
            # 修改URL为镜像
            response = requests.get(url, stream=True, timeout=60)
            response.raise_for_status()
            
            total_size = int(response.headers.get('content-length', 0))
            
            with open(path, 'wb') as f:
                if total_size > 0:
                    with tqdm(total=total_size, unit='B', unit_scale=True) as pbar:
                        for chunk in response.iter_content(chunk_size=8192):
                            if chunk:
                                f.write(chunk)
                                pbar.update(len(chunk))
                else:
                    for chunk in response.iter_content(chunk_size=8192):
                        if chunk:
                            f.write(chunk)
            
            if path.exists() and path.stat().st_size > 1024*1024:
                size_mb = path.stat().st_size / (1024*1024)
                print(f"   ✅ Python download success: {size_mb:.1f} MB")
            else:
                print(f"   ❌ Python download failed - file too small")
                
        except Exception as e:
            print(f"   ❌ Python download error: {e}")

# 如果需要，取消注释下面这行来运行Python备用下载
# python_download_fallback()

print(f"\n💡 If downloads still fail, you may need to:")
print(f"   • Use a VPN")
print(f"   • Try different network")
print(f"   • Download manually from browser")
print(f"   • Ask someone else to download and share files")

print(f"\n🎯 Once all files are downloaded, you can run:")
print(f"   python3 training/extract_video_training_latents_mps.py \\")
print(f"     --latent_dir ./output/latents \\")
print(f"     --output_dir ./output/memmap")
# Out:
# 🌐 Setting up mirror environment for China users
# ==================================================
# ✅ Set HF_ENDPOINT to: https://hf-mirror.com
#    HF_ENDPOINT = https://hf-mirror.com
#    HF_HUB_DISABLE_TELEMETRY = 1
#    HF_HUB_CACHE = /Users/yuqiliang/.cache/huggingface
#    CURL_TIMEOUT = 300
#
# 🔧 Testing mirror connectivity...
# ✅ Mirror connection successful!
#
# 📁 Creating directories...
#    • ext_weights: ext_weights
#    • weights: weights
#
# 📦 Files to download from mirror:
# • v1-16.pth (60MB)
#   └─ https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/ext_weights/v1-16.pth
# • synchformer_state_dict.pth (150MB)
#   └─ https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/ext_weights/synchformer_state_dict.pth
# • best_netG.pt (40MB)
#   └─ https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/ext_weights/best_netG.pt
# • mmaudio_small_16k.pth (600MB)
#   └─ https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/weights/mmaudio_small_16k.pth
#
# 🔍 Checking existing files...
# ❌ v1-16.pth missing
# ❌ synchformer_state_dict.pth missing
# ❌ best_netG.pt missing
# ❌ mmaudio_small_16k.pth missing
#
# 🚀 Downloading from mirror (hf-mirror.com)...
# =============================================
#
# 📥 Downloading v1-16.pth
#    📝 VAE model for 16kHz (~60MB)
#    🔗 https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/ext_weights/v1-16.pth
#    ⏳ Starting download...
# ######################################################################## 100.0%#=#=-#  #                                                                                                                                        3.0%                                                               4.7%                                                           16.4%##############################                                   55.4%
#    ✅ Success! Downloaded 654.8 MB
#
# 📥 Downloading synchformer_state_dict.pth
#    📝 Synchronization model (~150MB)
#    🔗 https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/ext_weights/synchformer_state_dict.pth
#    ⏳ Starting download...
# ######################################################################## 100.0%################                                          45.8%                62.9%########################################################         91.4%
#    ✅ Success! Downloaded 906.0 MB
#
# 📥 Downloading best_netG.pt
#    📝 Vocoder model (~40MB)
#    🔗 https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/ext_weights/best_netG.pt
#    ⏳ Starting download...
# ######################################################################## 100.0%#####                                                             18.1%################################################     96.2%
#    ✅ Success! Downloaded 428.4 MB
#
# 📥 Downloading mmaudio_small_16k.pth
#    📝 MMAudio Small model (~600MB)
#    🔗 https://hf-mirror.com/hkchengrex/MMAudio/resolve/main/weights/mmaudio_small_16k.pth
#    ⏳ Starting download...
# ######################################################################    98.4%########################                                 58.0%
#    ✅ Success! Downloaded 600.2 MB
#
# 🏁 Final Verification
# =========================
# ✅ v1-16.pth (654.8 MB)
# ✅ synchformer_state_dict.pth (906.0 MB)
# ✅ best_netG.pt (428.4 MB)
# ✅ mmaudio_small_16k.pth (600.2 MB)
#
# 📊 Summary:
#    Success: 4/4 files
#    Total size: 2589.5 MB
#
# 🎉 SUCCESS! All models downloaded
# ✅ Ready for feature extraction!
#
# 💡 If downloads still fail, you may need to:
#    • Use a VPN
#    • Try different network
#    • Download manually from browser
#    • Ask someone else to download and share files
#
# 🎯 Once all files are downloaded, you can run:
#    python3 training/extract_video_training_latents_mps.py \
#      --latent_dir ./output/latents \
#      --output_dir ./output/memmap
# ######################################################################## 100.0%

# %% [markdown]
# ## Check

# %%
#!/usr/bin/env python3
"""
Check Local MMAudio Feature Extraction Results
==============================================
Checks the status of feature extraction on local MacBook
"""

def check_extraction_results():
    """Check local feature extraction results"""
    import os
    from pathlib import Path
    
    # Local paths
    output_dir = Path('./output/memmap')
    feature_dir = output_dir / 'vgg-my_videos'  # Note: changed to vgg-my_videos
    
    print(f"🔍 Checking local feature extraction results...")
    print(f"   Output directory: {output_dir}")
    print(f"   Feature directory: {feature_dir}")
    
    # Check if output directory exists
    if not output_dir.exists():
        print("❌ Output directory does not exist")
        print(f"   Expected: {output_dir}")
        return False
    
    # Check if feature directory exists
    if not feature_dir.exists():
        print("❌ Feature directory does not exist")
        print(f"   Expected: {feature_dir}")
        
        # Check what directories do exist
        existing_dirs = [d for d in output_dir.iterdir() if d.is_dir()]
        if existing_dirs:
            print(f"   🔍 Found these directories instead:")
            for d in existing_dirs:
                print(f"      • {d.name}")
        
        return False
    
    # Check required feature files
    required_features = ['mean.memmap', 'std.memmap', 'clip_features.memmap', 
                        'sync_features.memmap', 'text_features.memmap', 'meta.json']
    
    print(f"\n📁 Checking feature files in: {feature_dir}")
    all_exist = True
    total_size_mb = 0
    
    for feature_file in required_features:
        file_path = feature_dir / feature_file
        if file_path.exists():
            if feature_file.endswith('.memmap'):
                size_mb = file_path.stat().st_size / (1024*1024)
                total_size_mb += size_mb
                print(f"   ✅ {feature_file} ({size_mb:.1f} MB)")
            else:
                print(f"   ✅ {feature_file}")
        else:
            print(f"   ❌ {feature_file} - missing")
            all_exist = False
    
    # Check TSV file
    tsv_file = output_dir / 'vgg-my_videos.tsv'  # Note: changed to vgg-my_videos
    print(f"\n📄 Checking TSV file: {tsv_file}")
    
    if tsv_file.exists():
        print(f"   ✅ vgg-my_videos.tsv exists")
        
        # Read and display statistics
        try:
            import pandas as pd
            df = pd.read_csv(tsv_file, sep='\t')
            print(f"   📊 Contains {len(df)} video samples")
            
            # Show sample data
            if len(df) > 0:
                print(f"   📋 Sample entries:")
                for i, row in df.head(3).iterrows():
                    print(f"      {i+1}. {row['id']}: {row['label']}")
                if len(df) > 3:
                    print(f"      ... and {len(df)-3} more")
        except Exception as e:
            print(f"   ❌ Error reading TSV: {e}")
            all_exist = False
    else:
        print(f"   ❌ vgg-my_videos.tsv - missing")
        all_exist = False
    
    # Final status
    if all_exist:
        print(f"\n🎉 Feature extraction completed successfully!")
        print(f"   📊 Total feature size: {total_size_mb:.1f} MB")
        print(f"   📁 Features saved locally")
        print(f"   ✅ Ready for training!")
        return True
    else:
        print(f"\n❌ Feature extraction incomplete")
        return False

def check_intermediate_files():
    """Check intermediate extraction files"""
    from pathlib import Path
    
    print(f"\n🔍 Checking intermediate files...")
    
    # Check latent directory
    latent_dir = Path('./output/latents/my_videos')
    if latent_dir.exists():
        batch_files = list(latent_dir.glob('*.pth'))
        print(f"   📁 Latent directory: {len(batch_files)} batch files")
        
        if batch_files:
            # Show range of files
            file_numbers = []
            for f in batch_files:
                try:
                    # Extract number from filename like r0_42.pth
                    parts = f.stem.split('_')
                    if len(parts) >= 2:
                        file_numbers.append(int(parts[1]))
                except:
                    continue
            
            if file_numbers:
                min_batch = min(file_numbers)
                max_batch = max(file_numbers)
                print(f"      Batch range: {min_batch} to {max_batch}")
                print(f"      Expected total batches: ~49 (based on 97 videos / 2 batch_size)")
                
                if max_batch >= 47:  # Close to expected 49 batches
                    print(f"      ✅ Most batches processed")
                else:
                    print(f"      ⚠️  Only reached batch {max_batch}")
    else:
        print(f"   ❌ No latent directory found")

def show_next_steps():
    """Show next steps based on current status"""
    print(f"\n🎯 Next Steps:")
    
    # Check what exists
    output_dir = Path('./output/memmap')
    feature_dir = output_dir / 'vgg-my_videos'
    latent_dir = Path('./output/latents/my_videos')
    
    if feature_dir.exists():
        print(f"   🎉 Feature extraction is complete!")
        print(f"   🚀 You can proceed with training:")
        print(f"      python3 train.py exp_id=my_fine_tuning model=small_16k")
        
    elif latent_dir.exists() and len(list(latent_dir.glob('*.pth'))) > 40:
        print(f"   🔄 Feature extraction was mostly completed but needs finishing")
        print(f"   💡 Try running extraction again - it should complete quickly:")
        print(f"      python3 training/extract_video_training_latents_mps.py \\")
        print(f"        --latent_dir ./output/latents \\")
        print(f"        --output_dir ./output/memmap")
        
    else:
        print(f"   ❌ Feature extraction needs to be run")
        print(f"   🔧 First fix the problematic video:")
        print(f"      mv training_videos/CamdenTown1_EQR_720p_190502_096.mp4 training_videos_problematic/")
        print(f"   📝 Update TSV file to remove the problematic entry")
        print(f"   🚀 Then run extraction:")
        print(f"      python3 training/extract_video_training_latents_mps.py \\")
        print(f"        --latent_dir ./output/latents \\")
        print(f"        --output_dir ./output/memmap")

def main():
    """Main function to check extraction status"""
    print("🔍 MMAudio Local Feature Extraction Status Check")
    print("=" * 50)
    
    # Check final results
    extraction_success = check_extraction_results()
    
    # Check intermediate files
    check_intermediate_files()
    
    # Show next steps
    show_next_steps()
    
    return extraction_success

if __name__ == "__main__":
    success = main()
    
    print(f"\n{'='*50}")
    if success:
        print("✅ Status: Feature extraction COMPLETE")
    else:
        print("⏳ Status: Feature extraction INCOMPLETE")
    print("="*50)
# Out:
# 🔍 MMAudio Local Feature Extraction Status Check
# ==================================================
# 🔍 Checking local feature extraction results...
#    Output directory: output/memmap
#    Feature directory: output/memmap/vgg-my_videos
#
# 📁 Checking feature files in: output/memmap/vgg-my_videos
#    ✅ mean.memmap (1.8 MB)
#    ✅ std.memmap (1.8 MB)
#    ✅ clip_features.memmap (24.0 MB)
#    ✅ sync_features.memmap (54.0 MB)
#    ✅ text_features.memmap (28.9 MB)
#    ✅ meta.json
#
# 📄 Checking TSV file: output/memmap/vgg-my_videos.tsv
#    ✅ vgg-my_videos.tsv exists
#    📊 Contains 96 video samples
#    📋 Sample entries:
#       1. CamdenTown1_EQR_720p_190502_000: audio from video
#       2. CamdenTown1_EQR_720p_190502_001: audio from video
#       3. CamdenTown1_EQR_720p_190502_002: audio from video
#       ... and 93 more
#
# 🎉 Feature extraction completed successfully!
#    📊 Total feature size: 110.5 MB
#    📁 Features saved locally
#    ✅ Ready for training!
#
# 🔍 Checking intermediate files...
#    📁 Latent directory: 0 batch files
#
# 🎯 Next Steps:
#    🎉 Feature extraction is complete!
#    🚀 You can proceed with training:
#       python3 train.py exp_id=my_fine_tuning model=small_16k
#
# ==================================================
# ✅ Status: Feature extraction COMPLETE
# ==================================================

# %%
#!/usr/bin/env python3
"""
检查MMAudio数据集样本数量和详细信息
用于诊断训练数据问题
"""

import os
import sys
from pathlib import Path
import pandas as pd
import tensordict as td
import torch
import json

def print_header(text):
    """打印标题"""
    print(f"\n{'='*60}")
    print(f"{text}")
    print(f"{'='*60}")

def print_info(label, value):
    """打印信息"""
    print(f"{label:<30}: {value}")

def check_video_directory(video_dir):
    """检查视频目录"""
    print_header("📁 视频文件检查")
    
    video_dir = Path(video_dir)
    if not video_dir.exists():
        print(f"❌ 目录不存在: {video_dir}")
        print(f"   请创建目录并添加视频文件")
        return 0
    
    # 支持的视频格式
    video_extensions = ['.mp4', '.avi', '.mov', '.mkv', '.webm', '.m4v', '.flv']
    video_files = []
    
    for ext in video_extensions:
        files = list(video_dir.glob(f'*{ext}')) + list(video_dir.glob(f'*{ext.upper()}'))
        video_files.extend(files)
    
    print_info("视频目录", str(video_dir))
    print_info("视频文件数量", len(video_files))
    
    if video_files:
        print(f"\n视频文件列表:")
        for i, video in enumerate(video_files[:10], 1):  # 只显示前10个
            size_mb = video.stat().st_size / (1024 * 1024)
            print(f"  {i}. {video.name} ({size_mb:.1f} MB)")
        
        if len(video_files) > 10:
            print(f"  ... 还有 {len(video_files)-10} 个文件")
    else:
        print("⚠️  没有找到视频文件!")
        print(f"   支持的格式: {', '.join(video_extensions)}")
    
    return len(video_files)

def check_tsv_file(tsv_path):
    """检查TSV文件"""
    print_header("📄 TSV元数据文件检查")
    
    tsv_path = Path(tsv_path)
    if not tsv_path.exists():
        print(f"❌ TSV文件不存在: {tsv_path}")
        return None
    
    try:
        df = pd.read_csv(tsv_path, sep='\t')
        
        print_info("TSV文件路径", str(tsv_path))
        print_info("总样本数", len(df))
        print_info("列名", list(df.columns))
        
        if 'id' in df.columns:
            print_info("唯一ID数量", df['id'].nunique())
            
            # 检查重复
            duplicates = df['id'].duplicated().sum()
            if duplicates > 0:
                print_info("重复ID数量", duplicates)
        
        if 'label' in df.columns:
            # 显示前5个标签
            print("\n前5个标签:")
            for i, label in enumerate(df['label'].head(5), 1):
                print(f"  {i}. {label[:100]}...")  # 只显示前100个字符
        
        return df
    except Exception as e:
        print(f"❌ 读取TSV文件失败: {e}")
        return None

def check_memmap_data(memmap_dir):
    """检查memory-mapped tensor数据"""
    print_header("💾 Memory-Mapped Tensor检查")
    
    memmap_dir = Path(memmap_dir)
    if not memmap_dir.exists():
        print(f"❌ Memmap目录不存在: {memmap_dir}")
        return None
    
    try:
        # 加载tensor dict
        print(f"加载数据从: {memmap_dir}")
        tensor_dict = td.TensorDict.load_memmap(memmap_dir)
        
        # 检查keys
        keys = list(tensor_dict.keys())
        print_info("可用的特征", keys)
        
        # 检查每个tensor的形状
        print("\n特征维度:")
        for key in keys:
            tensor = tensor_dict[key]
            print_info(f"  {key}", f"{tensor.shape} (dtype: {tensor.dtype})")
        
        # 获取样本数量
        if 'mean' in keys:
            num_samples = len(tensor_dict['mean'])
            print_info("\n总样本数", num_samples)
            
            # 检查数据有效性
            print("\n数据有效性检查:")
            for key in ['mean', 'std']:
                if key in keys:
                    tensor = tensor_dict[key]
                    has_nan = torch.isnan(tensor).any().item()
                    has_inf = torch.isinf(tensor).any().item()
                    print_info(f"  {key} 包含NaN", "是 ⚠️" if has_nan else "否 ✅")
                    print_info(f"  {key} 包含Inf", "是 ⚠️" if has_inf else "否 ✅")
            
            return num_samples
        
        return None
        
    except Exception as e:
        print(f"❌ 加载memmap数据失败: {e}")
        print(f"   错误详情: {str(e)}")
        return None

def check_training_data():
    """检查所有训练数据"""
    print("\n" + "="*60)
    print("🔍 MMAudio 训练数据完整性检查")
    print("="*60)
    
    # 1. 检查原始视频目录
    video_count = check_video_directory('./training_videos')
    
    # 2. 检查TSV文件（两个可能的位置）
    tsv_paths = [
        './training/my_video_train.tsv',  # 原始位置
        './output/memmap/vgg-my_videos.tsv'  # 生成后的位置
    ]
    
    tsv_df = None
    for tsv_path in tsv_paths:
        if Path(tsv_path).exists():
            tsv_df = check_tsv_file(tsv_path)
            break
    
    if tsv_df is None:
        print("\n⚠️  没有找到TSV文件，请先运行特征提取")
    
    # 3. 检查提取的特征
    memmap_dirs = [
        './output/memmap/vgg-my_videos',
        './fine_tuning_data/output/memmap/vgg-my_videos'
    ]
    
    num_samples = None
    for memmap_dir in memmap_dirs:
        if Path(memmap_dir).exists():
            num_samples = check_memmap_data(memmap_dir)
            break
    
    if num_samples is None:
        print("\n⚠️  没有找到提取的特征，请先运行特征提取脚本")
    
    # 4. 总结
    print_header("📊 数据集总结")
    
    if video_count > 0:
        print(f"✅ 找到 {video_count} 个视频文件")
    else:
        print("❌ 没有找到视频文件")
    
    if tsv_df is not None:
        print(f"✅ TSV文件包含 {len(tsv_df)} 条记录")
    else:
        print("❌ 没有找到TSV文件")
    
    if num_samples is not None:
        print(f"✅ 提取了 {num_samples} 个样本的特征")
        
        if num_samples < 2:
            print("\n⚠️  警告: 样本数量太少!")
            print("   至少需要2个样本才能训练（batch_size=2）")
            print("\n建议的解决方案:")
            print("   1. 添加更多视频到 ./training_videos/ 目录")
            print("   2. 重新运行特征提取脚本")
            print("   3. 或者在训练时使用 --batch_size 1")
    else:
        print("❌ 没有找到提取的特征")
        print("\n请运行特征提取脚本:")
        print("   python3 extract_video_training_latents_mps.py \\")
        print("     --latent_dir ./output/latents \\")
        print("     --output_dir ./output/memmap")
    
    # 5. 提供修复建议
    if num_samples == 1:
        print("\n" + "="*60)
        print("🔧 修复建议")
        print("="*60)
        print("\n您只有1个训练样本，有以下几种解决方案:")
        print("\n方案1: 添加更多视频")
        print("   1. 将更多视频文件放入 ./training_videos/")
        print("   2. 重新运行特征提取脚本")
        print("\n方案2: 修改训练参数")
        print("   运行训练时使用:")
        print("   python finetune_mmaudio_m1.py \\")
        print("     --exp_id experiment_01 \\")
        print("     --model small_16k \\")
        print("     --batch_size 1 \\")
        print("     --gradient_accumulation_steps 4")
        print("\n方案3: 使用数据增强")
        print("   可以通过复制现有样本来创建更多训练数据")
        print("   (注意: 这只是临时解决方案，不推荐用于实际训练)")

def create_dummy_samples(num_copies=5):
    """创建虚拟样本用于测试（不推荐用于实际训练）"""
    print_header("🔧 创建测试样本")
    
    memmap_dir = Path('./output/memmap/vgg-my_videos')
    if not memmap_dir.exists():
        print("❌ 没有找到原始数据")
        return
    
    print("⚠️  注意: 这只是用于测试，不应用于实际训练!")
    response = input("是否继续? (y/n): ")
    if response.lower() != 'y':
        return
    
    # 加载原始数据
    tensor_dict = td.TensorDict.load_memmap(memmap_dir)
    
    # 复制数据
    new_data = {}
    for key in tensor_dict.keys():
        original = tensor_dict[key]
        # 重复数据
        new_data[key] = original.repeat(num_copies, *[1] * (len(original.shape) - 1))
    
    # 保存新数据
    new_tensor_dict = td.TensorDict(new_data)
    new_memmap_dir = Path('./output/memmap/vgg-my_videos_augmented')
    new_tensor_dict.memmap_(new_memmap_dir)
    
    # 更新TSV文件
    tsv_path = Path('./output/memmap/vgg-my_videos.tsv')
    if tsv_path.exists():
        df = pd.read_csv(tsv_path, sep='\t')
        # 复制行
        new_df = pd.concat([df] * num_copies, ignore_index=True)
        # 更新ID以避免重复
        for i in range(len(new_df)):
            if i >= len(df):
                new_df.loc[i, 'id'] = f"{new_df.loc[i, 'id']}_copy_{i//len(df)}"
        
        new_tsv_path = Path('./output/memmap/vgg-my_videos_augmented.tsv')
        new_df.to_csv(new_tsv_path, sep='\t', index=False)
        
        print(f"✅ 创建了 {len(new_df)} 个样本")
        print(f"   数据保存在: {new_memmap_dir}")
        print(f"   TSV文件: {new_tsv_path}")
        print("\n训练时使用:")
        print("   python finetune_mmaudio_m1.py \\")
        print("     --data_dir ./output/memmap \\")
        print("     --tsv_file ./output/memmap/vgg-my_videos_augmented.tsv \\")
        print("     --exp_id test_augmented")

if __name__ == '__main__':
    # 运行检查
    check_training_data()
    
    # 如果只有一个样本，询问是否创建测试数据
    print("\n" + "="*60)
    print("如果需要创建测试数据，请运行:")
    print("python check_dataset.py --create-dummy")
    
    # 检查命令行参数
    if len(sys.argv) > 1 and sys.argv[1] == '--create-dummy':
        create_dummy_samples()
# Out:
# ============================================================
# 🔍 MMAudio 训练数据完整性检查
# ============================================================
#
# ============================================================
# 📁 视频文件检查
# ============================================================
# 视频目录                          : training_videos
# 视频文件数量                        : 20
#
# 视频文件列表:
#   1. CamdenTown1_EQR_720p_190502_007.mp4 (9.1 MB)
#   2. CamdenTown1_EQR_720p_190502_013.mp4 (9.0 MB)
#   3. CamdenTown1_EQR_720p_190502_012.mp4 (8.8 MB)
#   4. CamdenTown1_EQR_720p_190502_006.mp4 (9.3 MB)
#   5. CamdenTown1_EQR_720p_190502_010.mp4 (8.8 MB)
#   6. CamdenTown1_EQR_720p_190502_004.mp4 (8.8 MB)
#   7. CamdenTown1_EQR_720p_190502_005.mp4 (9.1 MB)
#   8. CamdenTown1_EQR_720p_190502_011.mp4 (9.2 MB)
#   9. CamdenTown1_EQR_720p_190502_015.mp4 (9.1 MB)
#   10. CamdenTown1_EQR_720p_190502_001.mp4 (8.0 MB)
#   ... 还有 10 个文件
#
# ============================================================
# 📄 TSV元数据文件检查
# ============================================================
# TSV文件路径                       : training/my_video_train.tsv
# 总样本数                          : 97
# 列名                            : ['id', 'label']
# 唯一ID数量                        : 97
#
# 前5个标签:
#   1. audio from video...
#   2. audio from video...
#   3. audio from video...
#   4. audio from video...
#   5. audio from video...
#
# ============================================================
# 💾 Memory-Mapped Tensor检查
# ============================================================
# 加载数据从: output/memmap/vgg-my_videos
# 可用的特征                         : ['mean', 'std', 'clip_features', 'sync_features', 'text_features']
#
# 特征维度:
#   mean                        : torch.Size([96, 250, 20]) (dtype: torch.float32)
#   std                         : torch.Size([96, 250, 20]) (dtype: torch.float32)
#   clip_features               : torch.Size([96, 64, 1024]) (dtype: torch.float32)
#   sync_features               : torch.Size([96, 192, 768]) (dtype: torch.float32)
#   text_features               : torch.Size([96, 77, 1024]) (dtype: torch.float32)
#
# 总样本数                         : 96
#
# 数据有效性检查:
#   mean 包含NaN                  : 否 ✅
#   mean 包含Inf                  : 否 ✅
#   std 包含NaN                   : 否 ✅
#   std 包含Inf                   : 否 ✅
#
# ============================================================
# 📊 数据集总结
# ============================================================
# ✅ 找到 20 个视频文件
# ✅ TSV文件包含 97 条记录
# ✅ 提取了 96 个样本的特征
#
# ============================================================
# 如果需要创建测试数据，请运行:
# python check_dataset.py --create-dummy

# %%
import av
container = av.open("/Users/yuqiliang/Documents/UCLPhD/pilot_study/output_split_stride10/CamdenMarket1_EQR_720p_0008.mp4")
print(container.streams)
# Out:
# <av.container.streams.StreamContainer object at 0x118311120>
